# %%
import numpy as np
import pandas as pd

# %%
mta = pd.read_csv("MTA Open Data Catalog.csv")

# %%
mta
# Out:
#     Open Dataset ID                             Dataset Name / Title  \
# 0                64            Access-A-Ride Call Center Performance
# 1                63  Access-A-Ride Customer Experience: 2018 to 2020
# 2               120       Access-A-Ride Drop-off On-Time Performance
# 3               121          Access-A-Ride Max Ride Time Performance
# 4                58         Access-A-Ride Pickup On-Time Performance
# ..              ...                                              ...
# 94               12        NYC Transit Subway Entrance And Exit Data
# 95                1   Arts For Transit - MTA Permanent Art Catalogue
# 96                3   Eye On The Future - MTA Contract Solicitations
# 97              204                            Procurement approvals
# 98              163                                   Service alerts
#
#                  Agency Posting Frequency  \
# 0                   AAR           Monthly
# 1                   AAR           Monthly
# ...
